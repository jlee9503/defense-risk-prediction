# %%
import os
from dotenv import load_dotenv
import pyodbc
import pandas as pd
from pathlib import Path
from sqlalchemy import create_engine

# Load environment variables
load_dotenv()

# Read values
server = os.getenv("DB_SERVER")
port = os.getenv("DB_PORT", "1433")  # Default SQL Server port
database = os.getenv("DB_NAME")
username = os.getenv("DB_USER")
password = os.getenv("DB_PASSWORD")

# Create connection string
connection_string = f"mssql+pyodbc://{username}:{password}@{server}:{port}/{database}?driver=ODBC+Driver+17+for+SQL+Server"

# Connect
conn = create_engine(connection_string)

# Define load_query function to load SQL queries from files
def load_query(name):
	path = Path("../scripts") / f"{name}.sql"
	if not path.exists():
		raise FileNotFoundError(f"Query file {path} does not exist.")
	return path.read_text()

# %% [markdown]
# # Load Dataset from SQL Database

# %%
# Load contracts data
contracts_df = pd.read_sql(load_query('get_contracts'), conn)
contracts_df
# Out:
#      contract_id supplier_id  contract_value_million  contract_type  \
# 0       CTR00000     SUP0056                    1.75            R&D
# 1       CTR00001     SUP0087                    6.18  Tech Services
# 2       CTR00002     SUP0224                    2.95            R&D
# 3       CTR00003     SUP0104                    0.23     Production
# 4       CTR00004     SUP0252                    0.13     Production
# ...          ...         ...                     ...            ...
# 4995    CTR04995     SUP0030                    8.05            R&D
# 4996    CTR04996     SUP0296                    3.46     Production
# 4997    CTR04997     SUP0095                    2.02     Production
# 4998    CTR04998     SUP0270                    0.14    Sustainment
# 4999    CTR04999     SUP0257                    2.42    Sustainment
#
#       award_date  expected_duration_months      status
# 0     2025-03-30                        37     delayed
# 1     2021-07-14                        25  terminated
# 2     2024-12-04                        15  terminated
# 3     2022-06-15                        34  terminated
# 4     2024-05-14                        46     delayed
# ...          ...                       ...         ...
# 4995  2022-11-04                        11   completed
# 4996  2023-12-18                        14   completed
# 4997  2020-06-03                        26   completed
# 4998  2020-07-18                        17     delayed
# 4999  2023-05-17                        35  terminated
#
# [5000 rows x 7 columns]

# %%
# Load suppliers data
suppliers_df = pd.read_sql(load_query('get_suppliers'), conn)
suppliers_df
# Out:
#     supplier_id                supplier_name  past_contracts  \
# 0       SUP0003                  Wiley-Moore              19
# 1       SUP0005         Liu, Jones and Jones              17
# 2       SUP0006                     Page LLC              30
# 3       SUP0008                   Potter PLC              29
# 4       SUP0011              Rogers and Sons              28
# ..          ...                          ...             ...
# 310     SUP0492               Garza-Hamilton              33
# 311     SUP0497                 Murphy Group               7
# 312     SUP0498  Pierce, Willis and Melendez               4
# 313     SUP0499                Bush and Sons              16
# 314     SUP0500                  Johnson-Day              27
#
#      average_delay_days  compliance_issues
# 0                     1                  1
# 1                   142                  3
# 2                   163                  1
# 3                     8                  0
# 4                    92                  2
# ..                  ...                ...
# 310                  68                  1
# 311                  35                  2
# 312                  45                  4
# 313                 110                  3
# 314                  27                  0
#
# [315 rows x 5 columns]

# %%
# Load delays data
delays_df = pd.read_sql(load_query('get_delays'), conn)
delays_df
# Out:
#      contract_id supplier_id  contract_value_million  contract_type  \
# 0       CTR00000     SUP0056                    1.75            R&D
# 1       CTR00004     SUP0252                    0.13     Production
# 2       CTR00005     SUP0374                    0.50    Sustainment
# 3       CTR00012     SUP0116                    3.08            R&D
# 4       CTR00013     SUP0395                    4.53     Production
# ...          ...         ...                     ...            ...
# 1264    CTR04977     SUP0344                    2.77            R&D
# 1265    CTR04989     SUP0194                    1.24     Production
# 1266    CTR04992     SUP0222                    1.27     Production
# 1267    CTR04994     SUP0337                    1.26  Tech Services
# 1268    CTR04998     SUP0270                    0.14    Sustainment
#
#       award_date  expected_duration_months   status  delay_days
# 0     2025-03-30                        37  delayed         153
# 1     2024-05-14                        46  delayed          99
# 2     2021-12-28                        57  delayed          99
# 3     2022-07-17                        12  delayed         149
# 4     2021-05-03                        11  delayed          31
# ...          ...                       ...      ...         ...
# 1264  2024-12-30                        43  delayed         104
# 1265  2020-09-23                        51  delayed         223
# 1266  2021-01-20                        33  delayed         121
# 1267  2023-02-07                        41  delayed         194
# 1268  2020-07-18                        17  delayed          30
#
# [1269 rows x 8 columns]

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
# Dataset Overview
print("Contracts Data Overview:")
contracts_df.info()
print("\nSuppliers Data Overview:")
suppliers_df.info()
print("\nDelays Data Overview:")
delays_df.info()
# Out:
# Contracts Data Overview:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   contract_id               5000 non-null   object
#  1   supplier_id               5000 non-null   object
#  2   contract_value_million    5000 non-null   float64
#  3   contract_type             5000 non-null   object
#  4   award_date                5000 non-null   object
#  5   expected_duration_months  5000 non-null   int64
#  6   status                    5000 non-null   object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 273.6+ KB
#
# Suppliers Data Overview:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 315 entries, 0 to 314
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   supplier_id         315 non-null    object
#  1   supplier_name       315 non-null    object
#  2   past_contracts      315 non-null    int64
#  3   average_delay_days  315 non-null    int64
#  4   compliance_issues   315 non-null    int64
# dtypes: int64(3), object(2)
# memory usage: 12.4+ KB
#
# Delays Data Overview:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1269 entries, 0 to 1268
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   contract_id               1269 non-null   object
#  1   supplier_id               1269 non-null   object
#  2   contract_value_million    1269 non-null   float64
#  3   contract_type             1269 non-null   object
#  4   award_date                1269 non-null   object
#  5   expected_duration_months  1269 non-null   int64
#  6   status                    1269 non-null   object
#  7   delay_days                1269 non-null   int64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 79.4+ KB
